# %% [markdown]
# ## Task 3.1 minst

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from model import VAE
import utils

# %%
############################################################
        ## Subtasks 3.3 & 3.4 in the worksheet ##
############################################################
# Set the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the MNIST dataset: Train and test 
train_dataset = MNIST(".", train=True, download=True, transform=ToTensor())
test_dataset = MNIST(".", train=False, download=True, transform=ToTensor())

# %%
# TODO: Set the learning rate, batch size and no. of epochs
lr = 0.001
batch_size = 128
num_epochs = 50

# %%
# TODO: Create an instance of Dataloader for train_dataset using torch.utils.data, use appropriate batch size, keep shuffle=True.
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
# TODO: Create an instance of Dataloader for test_dataset using torch.utils.data, use appropriate batch size, keep shuffle=False.
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# TODO: Set dimensions: input dim, latent dim, and no. of neurons in the hidden layer
input_dim = 784
latent_dim = 2
hidden_layer = 256

# %%
# TODO: Instantiate the VAE model with a latent dimension of 2, using the utility function instantiate_vae() from utils
model = utils.instantiate_vae(input_dim, latent_dim, hidden_layer)

# %%
# TODO. Set up an appropriate optimizer from torch.optim with an appropriate learning rate
optimizer = optim.Adam(model.parameters(), lr=lr)
plots_at_epochs = [0, 4, 24, 49]  # generate plots at epoch numbers

# %%
# TODO: Compute train and test losses by performing the training loop using the utility function training_loop() from utils
import importlib

# Reload the module to see changes
importlib.reload(utils)
train_losses, test_losses = utils.training_loop(model, optimizer, train_loader, test_loader, num_epochs, plots_at_epochs, device)
# Out:
# Epoch 1, Train Loss: 0.3890, Test Loss: 0.3413
# Epoch 2, Train Loss: 0.3265, Test Loss: 0.3224
# Epoch 3, Train Loss: 0.3119, Test Loss: 0.3112
# Epoch 4, Train Loss: 0.3024, Test Loss: 0.3035
# Epoch 5, Train Loss: 0.2965, Test Loss: 0.2978
# Epoch 6, Train Loss: 0.2923, Test Loss: 0.2945
# Epoch 7, Train Loss: 0.2891, Test Loss: 0.2908
# Epoch 8, Train Loss: 0.2866, Test Loss: 0.2881
# Epoch 9, Train Loss: 0.2840, Test Loss: 0.2876
# Epoch 10, Train Loss: 0.2822, Test Loss: 0.2863
# Epoch 11, Train Loss: 0.2810, Test Loss: 0.2836
# Epoch 12, Train Loss: 0.2797, Test Loss: 0.2841
# Epoch 13, Train Loss: 0.2783, Test Loss: 0.2822
# Epoch 14, Train Loss: 0.2781, Test Loss: 0.2818
# Epoch 15, Train Loss: 0.2764, Test Loss: 0.2806
# Epoch 16, Train Loss: 0.2752, Test Loss: 0.2794
# Epoch 17, Train Loss: 0.2743, Test Loss: 0.2789
# Epoch 18, Train Loss: 0.2737, Test Loss: 0.2785
# Epoch 19, Train Loss: 0.2727, Test Loss: 0.2780
# Epoch 20, Train Loss: 0.2726, Test Loss: 0.2776
# Epoch 21, Train Loss: 0.2717, Test Loss: 0.2765
# Epoch 22, Train Loss: 0.2711, Test Loss: 0.2767
# Epoch 23, Train Loss: 0.2704, Test Loss: 0.2763
# Epoch 24, Train Loss: 0.2701, Test Loss: 0.2752
# Epoch 25, Train Loss: 0.2693, Test Loss: 0.2751
# Epoch 26, Train Loss: 0.2690, Test Loss: 0.2747
# Epoch 27, Train Loss: 0.2686, Test Loss: 0.2748
# Epoch 28, Train Loss: 0.2685, Test Loss: 0.2739
# Epoch 29, Train Loss: 0.2681, Test Loss: 0.2738
# Epoch 30, Train Loss: 0.2675, Test Loss: 0.2732
# Epoch 31, Train Loss: 0.2673, Test Loss: 0.2736
# Epoch 32, Train Loss: 0.2669, Test Loss: 0.2731
# Epoch 33, Train Loss: 0.2666, Test Loss: 0.2737
# Epoch 34, Train Loss: 0.2661, Test Loss: 0.2733
# Epoch 35, Train Loss: 0.2660, Test Loss: 0.2728
# Epoch 36, Train Loss: 0.2664, Test Loss: 0.2724
# Epoch 37, Train Loss: 0.2655, Test Loss: 0.2730
# Epoch 38, Train Loss: 0.2654, Test Loss: 0.2721
# Epoch 39, Train Loss: 0.2650, Test Loss: 0.2717
# Epoch 40, Train Loss: 0.2647, Test Loss: 0.2710
# Epoch 41, Train Loss: 0.2648, Test Loss: 0.2717
# Epoch 42, Train Loss: 0.2641, Test Loss: 0.2715
# Epoch 43, Train Loss: 0.2642, Test Loss: 0.2709
# Epoch 44, Train Loss: 0.2637, Test Loss: 0.2704
# Epoch 45, Train Loss: 0.2631, Test Loss: 0.2701
# Epoch 46, Train Loss: 0.2630, Test Loss: 0.2710
# Epoch 47, Train Loss: 0.2629, Test Loss: 0.2701
# Epoch 48, Train Loss: 0.2629, Test Loss: 0.2700
# Epoch 49, Train Loss: 0.2623, Test Loss: 0.2702
# Epoch 50, Train Loss: 0.2622, Test Loss: 0.2701

# %%
# TODO: Plot the loss curve using the utility function plot_loss() from utils
plot_loss(train_losses, test_losses)

# %%
##############################################################
          ##### Subtask 3.5 in the worksheet #######
##############################################################
# Create the VAE model with a latent dimension of 32
# TODO: Repeat the above steps with the latent dimension of 32 and compute train and test losses
latent_dim = 32
model_dim_32 = instantiate_vae(input_dim, latent_dim, hidden_layer)
optimizer_dim_32 = optim.Adam(model_dim_32.parameters(), lr=lr)
train_losses_32, test_losses_32 = training_loop(model_dim_32, optimizer_dim_32, train_loader, test_loader, num_epochs, plots_at_epochs, device)
# Out:
# Epoch 1, Train Loss: 0.3951, Test Loss: 0.3302
# Epoch 2, Train Loss: 0.2972, Test Loss: 0.2766
# Epoch 3, Train Loss: 0.2674, Test Loss: 0.2619
# Epoch 4, Train Loss: 0.2571, Test Loss: 0.2538
# Epoch 5, Train Loss: 0.2497, Test Loss: 0.2478
# Epoch 6, Train Loss: 0.2442, Test Loss: 0.2427
# Epoch 7, Train Loss: 0.2404, Test Loss: 0.2396
# Epoch 8, Train Loss: 0.2373, Test Loss: 0.2373
# Epoch 9, Train Loss: 0.2347, Test Loss: 0.2340
# Epoch 10, Train Loss: 0.2323, Test Loss: 0.2318
# Epoch 11, Train Loss: 0.2300, Test Loss: 0.2303
# Epoch 12, Train Loss: 0.2285, Test Loss: 0.2295
# Epoch 13, Train Loss: 0.2270, Test Loss: 0.2271
# Epoch 14, Train Loss: 0.2257, Test Loss: 0.2262
# Epoch 15, Train Loss: 0.2247, Test Loss: 0.2260
# Epoch 16, Train Loss: 0.2237, Test Loss: 0.2242
# Epoch 17, Train Loss: 0.2230, Test Loss: 0.2240
# Epoch 18, Train Loss: 0.2222, Test Loss: 0.2239
# Epoch 19, Train Loss: 0.2216, Test Loss: 0.2235
# Epoch 20, Train Loss: 0.2210, Test Loss: 0.2224
# Epoch 21, Train Loss: 0.2203, Test Loss: 0.2220
# Epoch 22, Train Loss: 0.2198, Test Loss: 0.2222
# Epoch 23, Train Loss: 0.2192, Test Loss: 0.2211
# Epoch 24, Train Loss: 0.2186, Test Loss: 0.2212
# Epoch 25, Train Loss: 0.2185, Test Loss: 0.2212
# Epoch 26, Train Loss: 0.2181, Test Loss: 0.2200
# Epoch 27, Train Loss: 0.2177, Test Loss: 0.2198
# Epoch 28, Train Loss: 0.2173, Test Loss: 0.2198
# Epoch 29, Train Loss: 0.2169, Test Loss: 0.2193
# Epoch 30, Train Loss: 0.2167, Test Loss: 0.2187
# Epoch 31, Train Loss: 0.2165, Test Loss: 0.2192
# Epoch 32, Train Loss: 0.2162, Test Loss: 0.2190
# Epoch 33, Train Loss: 0.2159, Test Loss: 0.2188
# Epoch 34, Train Loss: 0.2156, Test Loss: 0.2187
# Epoch 35, Train Loss: 0.2154, Test Loss: 0.2182
# Epoch 36, Train Loss: 0.2151, Test Loss: 0.2187
# Epoch 37, Train Loss: 0.2149, Test Loss: 0.2180
# Epoch 38, Train Loss: 0.2148, Test Loss: 0.2171
# Epoch 39, Train Loss: 0.2143, Test Loss: 0.2188
# Epoch 40, Train Loss: 0.2144, Test Loss: 0.2180
# Epoch 41, Train Loss: 0.2142, Test Loss: 0.2176
# Epoch 42, Train Loss: 0.2142, Test Loss: 0.2171
# Epoch 43, Train Loss: 0.2138, Test Loss: 0.2172
# Epoch 44, Train Loss: 0.2137, Test Loss: 0.2170
# Epoch 45, Train Loss: 0.2134, Test Loss: 0.2178
# Epoch 46, Train Loss: 0.2135, Test Loss: 0.2170
# Epoch 47, Train Loss: 0.2132, Test Loss: 0.2170
# Epoch 48, Train Loss: 0.2131, Test Loss: 0.2165
# Epoch 49, Train Loss: 0.2129, Test Loss: 0.2163
# Epoch 50, Train Loss: 0.2128, Test Loss: 0.2170

# %%
# TODO: (5a) Compare 15 generated digits using the utility function reconstruct_digits()
reconstruct_digits(model, test_loader, device)
reconstruct_digits(model_dim_32, test_loader, device)

# %%
# TODO: (5b) Plot the loss curve using the utility function plot_loss()
plot_loss(train_losses_32, test_losses_32)
