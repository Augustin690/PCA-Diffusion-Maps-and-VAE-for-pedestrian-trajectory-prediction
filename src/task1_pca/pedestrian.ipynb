# %%
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
""" Task 1.3: In this script, we apply principal component analysis to pedestrian trajectory data. 
We need functions defined in utils.py for this script.
"""

# TODO: Load trajectory data in data_DMAP_PCA_Vadere.txt. (Hint: You may need to use a space as delimiter)
data = np.loadtxt('../../data/data_DMAP_PCA_Vadere.txt', delimiter=' ')

# %%
data.shape
# Out:
# (1000, 30)

# %%
# TODO: Extract positions of pedestrians 1 and 2
pedestrian_1 = data[:, 2:4]
pedestrian_2 = data[:, 29:31]
# TODO: Visualize trajectories of first two pedestrians (Hint: You can optionally use utils.visualize_traj_two_pedestrians() )
utils.visualize_traj_two_pedestrians(pedestrian_1, pedestrian_2, ('trajectories', 'x', 'y'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3 pedestrian_2 = data[:, 29:31]
#       4 # TODO: Visualize trajectories of first two pedestrians (Hint: You can optionally use utils.visualize_traj_two_pedestrians() )
# ----> 5 utils.visualize_traj_two_pedestrians(pedestrian_1, pedestrian_2, ('trajectories', 'x', 'y'))
#       6 plt.show()
#
# File c:\Users\Augustin\OneDrive\Bureau\PycharmProjects\TUM\SOS2024\Practical_Course\mlicms24ex3-groupf\src\task1_pca\utils.py:192, in visualize_traj_two_pedestrians(p1, p2, title_axes_labels)
#     190 plt.subplot(1, 2, 1)
#     191 plt.plot(p1[:, 0], p1[:, 1], label='Pedestrian 1')
# --> 192 plt.plot(p2[:, 0], p2[:, 1], label='Pedestrian 2')
#     193 plt.title(title_axes_labels[0])
#     194 plt.xlabel(title_axes_labels[1])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
#We got 15 pedestrians in this dataset !
